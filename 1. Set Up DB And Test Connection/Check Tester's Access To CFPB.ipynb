# %%
# !pip install "cloud-sql-python-connector[pg8000]"
# !pip install psycopg2

# %%
import psycopg2
from psycopg2 import extras
import pandas as pd

# %%
# Replace these with your actual details
user="xxxxx"
password="xxxxx"
database = "cfpb"
host = "xx.xx.xx.xx"

# Connect to your postgres server
conn = psycopg2.connect(
    dbname=database,
    user=user,
    password=password,
    host=host
)
# Create a cursor object
cur = conn.cursor()

# %%
query = f"""
SELECT *
FROM cfpb
ORDER BY random()
LIMIT 100;
"""

# # Method 1
# # Fetch data in chunks
# chunk_size = 10000  # you can adjust this value depending on your system's memory and requirements
# chunks = []
# for chunk in pd.read_sql_query(query, conn, chunksize=chunk_size):
#     # process data in chunks as needed, or save each chunk for later processing
#     chunks.append(chunk)

# # Combine chunks into one DataFrame
# df = pd.concat(chunks)


# # Method 2
# # Execute the query
# cur.execute(query)
# # Fetch all rows
# rows = cur.fetchall()
# # Get the column names
# colnames = [desc[0] for desc in cur.description]
# # Convert to DataFrame
# df = pd.DataFrame(rows, columns=colnames)

# Method 3
df = pd.read_sql_query(query, conn)
df
# Out:
# C:\Users\JYM\anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#          id Date_received                                            Product  \
# 0   1862118    2021-10-03  Credit reporting, credit repair services, or o...
# 1    753955    2019-02-24  Credit reporting, credit repair services, or o...
# 2    216585    2018-05-04  Credit reporting, credit repair services, or o...
# 3   2378047    2021-10-29  Credit reporting, credit repair services, or o...
# 4   2480955    2014-02-13                                    Debt collection
# ..      ...           ...                                                ...
# 95  2852711    2014-06-18                                           Mortgage
# 96  1667226    2020-11-05  Credit reporting, credit repair services, or o...
# 97  2308568    2018-08-09  Credit reporting, credit repair services, or o...
# 98  2434254    2021-05-28  Credit reporting, credit repair services, or o...
# 99  2087849    2021-03-25                                    Debt collection
#
#                     Sub_product  \
# 0              Credit reporting
# 1              Credit reporting
# 2              Credit reporting
# 3              Credit reporting
# 4                 I do not know
# ..                          ...
# 95  Conventional fixed mortgage
# 96             Credit reporting
# 97             Credit reporting
# 98             Credit reporting
# 99                 Medical debt
#
#                                                 Issue  \
# 0   Problem with a credit reporting company's inve...
# 1                Incorrect information on your report
# 2                Incorrect information on your report
# 3   Problem with a credit reporting company's inve...
# 4               Cont'd attempts collect debt not owed
# ..                                                ...
# 95           Loan servicing, payments, escrow account
# 96                        Improper use of your report
# 97               Incorrect information on your report
# 98               Incorrect information on your report
# 99                 False statements or representation
#
#                                             Sub_issue  \
# 0   Their investigation did not fix an error on yo...
# 1                 Information belongs to someone else
# 2                      Personal information incorrect
# 3   Their investigation did not fix an error on yo...
# 4                                    Debt is not mine
# ..                                                ...
# 95                                                NaN
# 96  Credit inquiries on your report that you don't...
# 97                      Account information incorrect
# 98                Information belongs to someone else
# 99                  Attempted to collect wrong amount
#
#                          Consumer_complaint_narrative  \
# 0   Submitted multiple disputes with all three cre...
# 1   Starting on XX/XX/XXXX I started the process o...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96  On XX/XX/2020, a sales person contacted me fro...
# 97  I checked my credit score and noticed 4 late p...
# 98                                                NaN
# 99  Collection Bureau of Ft. Walton Beach , INC se...
#
#                               Company_public_response  \
# 0                                                 NaN
# 1   Company has responded to the consumer and the ...
# 2   Company has responded to the consumer and the ...
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97  Company has responded to the consumer and the ...
# 98                                                NaN
# 99                                                NaN
#
#                                         Company State ZIP_code  \
# 0                                 EQUIFAX, INC.    CA  92308.0
# 1           Experian Information Solutions Inc.    SC  29609.0
# 2        TRANSUNION INTERMEDIATE HOLDINGS, INC.    TX    76549
# 3                                 EQUIFAX, INC.    MA   2302.0
# 4               Resurgent Capital Services L.P.    FL  34677.0
# ..                                          ...   ...      ...
# 95                  Ocwen Financial Corporation    TX    76028
# 96            Consumer Portfolio Services, Inc.    AL    35215
# 97        BANK OF AMERICA, NATIONAL ASSOCIATION    TX    77002
# 98                                EQUIFAX, INC.    MO    63136
# 99  Collection Bureau of Fort Walton Beach, Inc    NM    87120
#
#               Tags Consumer_consent_provided Submitted_via  \
# 0              NaN          Consent provided           Web
# 1              NaN          Consent provided           Web
# 2              NaN      Consent not provided           Web
# 3              NaN      Consent not provided           Web
# 4              NaN                       NaN           Web
# ..             ...                       ...           ...
# 95  Older American                       NaN           Web
# 96             NaN          Consent provided           Web
# 97             NaN          Consent provided           Web
# 98             NaN      Consent not provided           Web
# 99   Servicemember          Consent provided           Web
#
#    Date_sent_to_company     Company_response_to_consumer Timely_response  \
# 0            2021-10-03          Closed with explanation             Yes
# 1            2019-02-24          Closed with explanation             Yes
# 2            2018-05-05  Closed with non-monetary relief             Yes
# 3            2021-10-29          Closed with explanation             Yes
# 4            2014-03-01          Closed with explanation             Yes
# ..                  ...                              ...             ...
# 95           2014-06-20          Closed with explanation             Yes
# 96           2020-11-05          Closed with explanation             Yes
# 97           2018-08-09          Closed with explanation             Yes
# 98           2021-05-28          Closed with explanation             Yes
# 99           2021-03-25          Closed with explanation             Yes
#
#    Consumer_disputed  Complaint_ID
# 0                NaN       4775555
# 1                NaN       3161700
# 2                NaN       2897215
# 3                NaN       4859061
# 4                Yes        713173
# ..               ...           ...
# 95                No        899601
# 96               NaN       3937453
# 97               NaN       2986673
# 98               NaN       4413466
# 99               NaN       4243059
#
# [100 rows x 19 columns]

# %%
# Close the cursor and connection
cur.close()
conn.close()
