# %%
# !pip install "cloud-sql-python-connector[pg8000]"
# !pip install psycopg2

# %%
import psycopg2
from psycopg2 import extras
import pandas as pd

# %%
# Replace these with your actual details
user="xxxxx"
password="xxxxx"
database = "cfpb"
host = "xx.xx.xx.xx"

# Connect to your postgres server
conn = psycopg2.connect(
    dbname=database,
    user=user,
    password=password,
    host=host
)
# Create a cursor object
cur = conn.cursor()

# %%
# A quick sanity check

# Execute a query
cur.execute("SELECT NOW()")
# Fetch the result
result = cur.fetchone()
print(f"Current time: {result[0]}")
# Out:
# Current time: 2023-07-05 02:31:06.945207+00:00

# %%
cfpb = pd.read_csv("complaints-2023-07-04_01_06.csv")

# %%
cfpb.columns
# Out:
# Index(['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue',
#        'Consumer complaint narrative', 'Company public response', 'Company',
#        'State', 'ZIP code', 'Tags', 'Consumer consent provided?',
#        'Submitted via', 'Date sent to company', 'Company response to consumer',
#        'Timely response?', 'Consumer disputed?', 'Complaint ID'],
#       dtype='object')

# %%
cfpb.dtypes
# Out:
# Date received                    object
# Product                          object
# Sub-product                      object
# Issue                            object
# Sub-issue                        object
# Consumer complaint narrative     object
# Company public response          object
# Company                          object
# State                            object
# ZIP code                         object
# Tags                             object
# Consumer consent provided?       object
# Submitted via                    object
# Date sent to company             object
# Company response to consumer     object
# Timely response?                 object
# Consumer disputed?              float64
# Complaint ID                      int64
# dtype: object

# %%
cfpb_sample = cfpb[~cfpb['Consumer complaint narrative'].isna()].sample(100)

# %%
# Convert 'Date_received' and 'Date_sent_to_company' from 'mm/dd/yy' to 'yyyy-mm-dd'
cfpb_sample['Date received'] = pd.to_datetime(cfpb_sample['Date received'], format='%m/%d/%y').dt.strftime('%Y-%m-%d')
cfpb_sample['Date sent to company'] = pd.to_datetime(cfpb_sample['Date sent to company'], format='%m/%d/%y').dt.strftime('%Y-%m-%d')
cfpb_sample['Complaint ID'].fillna(0, inplace=True)
cfpb_sample['Complaint ID'] = cfpb_sample['Complaint ID'].astype(float)

# %%
cfpb_sample.dtypes
# Out:
# Date received                    object
# Product                          object
# Sub-product                      object
# Issue                            object
# Sub-issue                        object
# Consumer complaint narrative     object
# Company public response          object
# Company                          object
# State                            object
# ZIP code                         object
# Tags                             object
# Consumer consent provided?       object
# Submitted via                    object
# Date sent to company             object
# Company response to consumer     object
# Timely response?                 object
# Consumer disputed?              float64
# Complaint ID                    float64
# dtype: object

# %%
# create a dictionary to map old column names to new column names
rename_dict = {
    'Date received': 'Date_received',
    'Product': 'Product',
    'Sub-product': 'Sub_product',
    'Issue': 'Issue',
    'Sub-issue': 'Sub_issue',
    'Consumer complaint narrative': 'Consumer_complaint_narrative',
    'Company public response': 'Company_public_response',
    'Company': 'Company',
    'State': 'State',
    'ZIP code': 'ZIP_code',
    'Tags': 'Tags',
    'Consumer consent provided?': 'Consumer_consent_provided',
    'Submitted via': 'Submitted_via',
    'Date sent to company': 'Date_sent_to_company',
    'Company response to consumer': 'Company_response_to_consumer',
    'Timely response?': 'Timely_response',
    'Consumer disputed?': 'Consumer_disputed',
    'Complaint ID': 'Complaint_ID'
}

# rename the columns
cfpb_sample.rename(columns=rename_dict, inplace=True)
cfpb_sample
# Out:
#        Date_received                                            Product  \
# 56007     2023-04-18  Credit reporting, credit repair services, or o...
# 45732     2023-04-11  Credit reporting, credit repair services, or o...
# 218786    2023-04-22  Credit reporting, credit repair services, or o...
# 172834    2023-04-24  Credit reporting, credit repair services, or o...
# 248570    2023-05-01  Credit reporting, credit repair services, or o...
# ...              ...                                                ...
# 102728    2023-04-20  Credit reporting, credit repair services, or o...
# 53843     2023-04-17  Credit reporting, credit repair services, or o...
# 284290    2023-04-19  Credit reporting, credit repair services, or o...
# 142761    2023-04-22  Credit reporting, credit repair services, or o...
# 210466    2023-04-29  Credit reporting, credit repair services, or o...
#
#              Sub_product                                              Issue  \
# 56007   Credit reporting               Incorrect information on your report
# 45732   Credit reporting                        Improper use of your report
# 218786  Credit reporting               Incorrect information on your report
# 172834  Credit reporting               Incorrect information on your report
# 248570  Credit reporting  Problem with a credit reporting company's inve...
# ...                  ...                                                ...
# 102728  Credit reporting  Problem with a credit reporting company's inve...
# 53843   Credit reporting  Problem with a credit reporting company's inve...
# 284290  Credit reporting               Incorrect information on your report
# 142761  Credit reporting                        Improper use of your report
# 210466  Credit reporting  Problem with a credit reporting company's inve...
#
#                                                 Sub_issue  \
# 56007                 Information belongs to someone else
# 45732       Reporting company used your report improperly
# 218786                      Account information incorrect
# 172834                Information belongs to someone else
# 248570  Their investigation did not fix an error on yo...
# ...                                                   ...
# 102728  Difficulty submitting a dispute or getting inf...
# 53843   Their investigation did not fix an error on yo...
# 284290                Information belongs to someone else
# 142761      Reporting company used your report improperly
# 210466  Their investigation did not fix an error on yo...
#
#                              Consumer_complaint_narrative  \
# 56007   My name is XXXX XXXX XXXX XXXX this complaint ...
# 45732   In accordance with the Fair Credit Reporting a...
# 218786  XX/XX/2021 XXXX XXXX XXXX XXXX closed my accou...
# 172834  I want to inform the Credit Bureaus that I was...
# 248570  This is my numerous request that you amend thi...
# ...                                                   ...
# 102728  Though it does credit card business in the mil...
# 53843   When I reviewed my credit report, I discovered...
# 284290  Please remove these Fraudulent accounts from m...
# 142761  In accordance with the Fair Credit Reporting a...
# 210466  I have sent numerous letters to the credit bur...
#
#                                   Company_public_response  \
# 56007                                                None
# 45732   Company has responded to the consumer and the ...
# 218786  Company has responded to the consumer and the ...
# 172834  Company has responded to the consumer and the ...
# 248570  Company has responded to the consumer and the ...
# ...                                                   ...
# 102728  Company has responded to the consumer and the ...
# 53843   Company has responded to the consumer and the ...
# 284290  Company has responded to the consumer and the ...
# 142761  Company has responded to the consumer and the ...
# 210466  Company has responded to the consumer and the ...
#
#                                        Company State ZIP_code  Tags  \
# 56007      Experian Information Solutions Inc.    PA    15001  None
# 45732      Experian Information Solutions Inc.    KS    66030  None
# 218786  TRANSUNION INTERMEDIATE HOLDINGS, INC.    DE    19701  None
# 172834  TRANSUNION INTERMEDIATE HOLDINGS, INC.    CA    92881  None
# 248570  TRANSUNION INTERMEDIATE HOLDINGS, INC.    VA    22405  None
# ...                                        ...   ...      ...   ...
# 102728                            U.S. BANCORP    MI    48168  None
# 53843   TRANSUNION INTERMEDIATE HOLDINGS, INC.    LA    70122  None
# 284290     Experian Information Solutions Inc.    FL    33162  None
# 142761  TRANSUNION INTERMEDIATE HOLDINGS, INC.    TX    76137  None
# 210466     Experian Information Solutions Inc.    GA    30228  None
#
#        Consumer_consent_provided Submitted_via Date_sent_to_company  \
# 56007           Consent provided           Web           2023-04-18
# 45732           Consent provided           Web           2023-04-11
# 218786          Consent provided           Web           2023-04-22
# 172834          Consent provided           Web           2023-04-24
# 248570          Consent provided           Web           2023-05-01
# ...                          ...           ...                  ...
# 102728          Consent provided           Web           2023-04-20
# 53843           Consent provided           Web           2023-04-17
# 284290          Consent provided           Web           2023-04-19
# 142761          Consent provided           Web           2023-04-22
# 210466          Consent provided           Web           2023-04-29
#
#            Company_response_to_consumer Timely_response  Consumer_disputed  \
# 56007           Closed with explanation             Yes                NaN
# 45732           Closed with explanation             Yes                NaN
# 218786  Closed with non-monetary relief             Yes                NaN
# 172834  Closed with non-monetary relief             Yes                NaN
# 248570  Closed with non-monetary relief             Yes                NaN
# ...                                 ...             ...                ...
# 102728          Closed with explanation             Yes                NaN
# 53843           Closed with explanation             Yes                NaN
# 284290          Closed with explanation             Yes                NaN
# 142761  Closed with non-monetary relief             Yes                NaN
# 210466          Closed with explanation             Yes                NaN
#
#         Complaint_ID
# 56007      6856028.0
# 45732      6826594.0
# 218786     6875861.0
# 172834     6878070.0
# 248570     6912216.0
# ...              ...
# 102728     6860880.0
# 53843      6846108.0
# 284290     6862517.0
# 142761     6871543.0
# 210466     6907876.0
#
# [100 rows x 18 columns]

# %%
# Create table
table_creation_query = """
    CREATE TABLE cfpb (
        id SERIAL PRIMARY KEY,
        "Date_received" DATE,
        "Product" VARCHAR(255),
        "Sub_product" VARCHAR(255),
        "Issue" VARCHAR(255),
        "Sub_issue" VARCHAR(255),
        "Consumer_complaint_narrative" TEXT,
        "Company_public_response" VARCHAR(255),
        "Company" VARCHAR(255),
        "State" VARCHAR(255),
        "ZIP_code" VARCHAR(255),
        "Tags" VARCHAR(255),
        "Consumer_consent_provided" VARCHAR(255),
        "Submitted_via" VARCHAR(255),
        "Date_sent_to_company" DATE,
        "Company_response_to_consumer" VARCHAR(255),
        "Timely_response" VARCHAR(255),
        "Consumer_disputed" VARCHAR(255),
        "Complaint_ID" INT UNIQUE
    );
"""

cur.execute(table_creation_query)
# Commit your changes
conn.commit()

# %%
# Convert DataFrame to a list of tuples
records = cfpb_sample.to_records(index=False)
result = list(records)

insert_query_base = """
INSERT INTO cfpb ("Date_received", "Product", "Sub_product", "Issue", "Sub_issue", "Consumer_complaint_narrative", 
"Company_public_response", "Company", "State", "ZIP_code", "Tags", "Consumer_consent_provided", "Submitted_via", 
"Date_sent_to_company", "Company_response_to_consumer", "Timely_response", "Consumer_disputed", "Complaint_ID") 
VALUES %s ON CONFLICT ("Complaint_ID") DO NOTHING
"""
psycopg2.extras.execute_values(cur, insert_query_base, result)

# Commit your changes
conn.commit()

# %%
query = "SELECT * FROM cfpb"

# # Method 1
# # Fetch data in chunks
# chunk_size = 10000  # you can adjust this value depending on your system's memory and requirements
# chunks = []
# for chunk in pd.read_sql_query(query, conn, chunksize=chunk_size):
#     # process data in chunks as needed, or save each chunk for later processing
#     chunks.append(chunk)

# # Combine chunks into one DataFrame
# df = pd.concat(chunks)


# # Method 2
# # Execute the query
# cur.execute(query)
# # Fetch all rows
# rows = cur.fetchall()
# # Get the column names
# colnames = [desc[0] for desc in cur.description]
# # Convert to DataFrame
# df = pd.DataFrame(rows, columns=colnames)

# Method 3
df = pd.read_sql_query(query, conn)
df
# Out:
# C:\Users\JYM\anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#       id Date_received                                            Product  \
# 0      1    2023-04-07  Credit reporting, credit repair services, or o...
# 1      2    2023-05-05          Payday loan, title loan, or personal loan
# 2      3    2023-04-30  Credit reporting, credit repair services, or o...
# 3      4    2023-06-15  Credit reporting, credit repair services, or o...
# 4      5    2023-04-06  Credit reporting, credit repair services, or o...
# ..   ...           ...                                                ...
# 195  196    2023-04-20  Credit reporting, credit repair services, or o...
# 196  197    2023-04-17  Credit reporting, credit repair services, or o...
# 197  198    2023-04-19  Credit reporting, credit repair services, or o...
# 198  199    2023-04-22  Credit reporting, credit repair services, or o...
# 199  200    2023-04-29  Credit reporting, credit repair services, or o...
#
#           Sub_product                                              Issue  \
# 0    Credit reporting  Problem with a credit reporting company's inve...
# 1          Title loan  Problem with the payoff process at the end of ...
# 2    Credit reporting                        Improper use of your report
# 3    Credit reporting               Incorrect information on your report
# 4    Credit reporting                        Improper use of your report
# ..                ...                                                ...
# 195  Credit reporting  Problem with a credit reporting company's inve...
# 196  Credit reporting  Problem with a credit reporting company's inve...
# 197  Credit reporting               Incorrect information on your report
# 198  Credit reporting                        Improper use of your report
# 199  Credit reporting  Problem with a credit reporting company's inve...
#
#                                              Sub_issue  \
# 0    Was not notified of investigation status or re...
# 1                                                 None
# 2        Reporting company used your report improperly
# 3                  Information belongs to someone else
# 4    Credit inquiries on your report that you don't...
# ..                                                 ...
# 195  Difficulty submitting a dispute or getting inf...
# 196  Their investigation did not fix an error on yo...
# 197                Information belongs to someone else
# 198      Reporting company used your report improperly
# 199  Their investigation did not fix an error on yo...
#
#                           Consumer_complaint_narrative  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 195  Though it does credit card business in the mil...
# 196  When I reviewed my credit report, I discovered...
# 197  Please remove these Fraudulent accounts from m...
# 198  In accordance with the Fair Credit Reporting a...
# 199  I have sent numerous letters to the credit bur...
#
#                                Company_public_response  \
# 0    Company has responded to the consumer and the ...
# 1                                                 None
# 2    Company has responded to the consumer and the ...
# 3                                                 None
# 4    Company has responded to the consumer and the ...
# ..                                                 ...
# 195  Company has responded to the consumer and the ...
# 196  Company has responded to the consumer and the ...
# 197  Company has responded to the consumer and the ...
# 198  Company has responded to the consumer and the ...
# 199  Company has responded to the consumer and the ...
#
#                                     Company State ZIP_code  Tags  \
# 0       Experian Information Solutions Inc.    IN    46214  None
# 1              SANTANDER HOLDINGS USA, INC.    NJ    08618  None
# 2       Experian Information Solutions Inc.    FL    34746  None
# 3    TRANSUNION INTERMEDIATE HOLDINGS, INC.    TX    77065  None
# 4              TRUIST FINANCIAL CORPORATION    FL    33129  None
# ..                                      ...   ...      ...   ...
# 195                            U.S. BANCORP    MI    48168  None
# 196  TRANSUNION INTERMEDIATE HOLDINGS, INC.    LA    70122  None
# 197     Experian Information Solutions Inc.    FL    33162  None
# 198  TRANSUNION INTERMEDIATE HOLDINGS, INC.    TX    76137  None
# 199     Experian Information Solutions Inc.    GA    30228  None
#
#     Consumer_consent_provided Submitted_via Date_sent_to_company  \
# 0        Consent not provided           Web           2023-04-07
# 1                         NaN         Phone           2023-05-09
# 2        Consent not provided           Web           2023-04-30
# 3                        None           Web           2023-06-15
# 4        Consent not provided           Web           2023-04-06
# ..                        ...           ...                  ...
# 195          Consent provided           Web           2023-04-20
# 196          Consent provided           Web           2023-04-17
# 197          Consent provided           Web           2023-04-19
# 198          Consent provided           Web           2023-04-22
# 199          Consent provided           Web           2023-04-29
#
#         Company_response_to_consumer Timely_response Consumer_disputed  \
# 0            Closed with explanation             Yes               NaN
# 1    Closed with non-monetary relief             Yes               NaN
# 2            Closed with explanation             Yes               NaN
# 3                        In progress             Yes               NaN
# 4            Closed with explanation             Yes               NaN
# ..                               ...             ...               ...
# 195          Closed with explanation             Yes               NaN
# 196          Closed with explanation             Yes               NaN
# 197          Closed with explanation             Yes               NaN
# 198  Closed with non-monetary relief             Yes               NaN
# 199          Closed with explanation             Yes               NaN
#
#      Complaint_ID
# 0         6802950
# 1         6942452
# 2         6909361
# 3         7122705
# 4         6804505
# ..            ...
# 195       6860880
# 196       6846108
# 197       6862517
# 198       6871543
# 199       6907876
#
# [200 rows x 19 columns]

# %%
# Close the cursor and connection
cur.close()
conn.close()
